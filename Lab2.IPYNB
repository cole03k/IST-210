# %% [markdown]
# ![PsuLab2.png](attachment:PsuLab2.png)

# %%
##For this assignment I layed out five main primary keys for the pet shop. The keys I used were Pet, Pet Enclosure, Customer,
##Pet Food, Employee, Loyalty Member. I chose these because I felt they were the most basic and necessary entities to run the 
##pet shop properly using the database. I used my Pet key to connect it to the Pet food key as well as the Enclosure key. The 
##Pet_Id will hold much of the info for the pet like age, sex, and breed. You use this info to determine which type of food is
##the best for the pet. I used a type of pet as a foreign key for my Pet enclosure primary key because it would only make 
##sense to keep the same species in the same unit. The loyalty member primary key was really used to just determine if the 
##customer was a member or not by storing all of the loyalty member’s customer IDs in that database. If the customer is a 
##loyalty member then discounts get applied to the price of pet food, pets, and total final cost. The employee database just 
##retrieves the customer information and applies rewards if they are a loyalty member.
